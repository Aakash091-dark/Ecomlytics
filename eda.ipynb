# %%
import pandas as pd

# %%
data_path = "data\data.csv"
df = pd.read_csv(data_path)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Aakash\AppData\Local\Temp\ipykernel_21444\1072020049.py:1: SyntaxWarning: invalid escape sequence '\d'
#   data_path = "data\data.csv"

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.head()
# Out:
#                          \tEmail  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0         835 Frank TunnelWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer CommonDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582Cobbborough, DC ...            Bisque
# 3     1414 David ThroughwayPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez PassagePort Jacobville, PR 372...  MediumAquaMarine
#
#    Time on App  Time on Website  Length of Membership  Yearly Amount Spent
# 0        12.66            39.58                  4.08               587.95
# 1        11.11            37.27                  2.66               392.20
# 2        11.33            37.11                  4.10               487.55
# 3        13.72            36.72                  3.12               581.85
# 4        12.80            37.54                  4.45               599.41

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   	Email                500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Time on App           500 non-null    float64
#  4   Time on Website       500 non-null    float64
#  5   Length of Membership  500 non-null    float64
#  6   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(4), object(3)
# memory usage: 27.5+ KB

# %%
df.describe()
# Out:
#        Time on App  Time on Website  Length of Membership  Yearly Amount Spent
# count   500.000000       500.000000             500.00000           500.000000
# mean     12.052620        37.060480               3.53336           499.314240
# std       0.994418         1.010555               0.99926            79.314764
# min       8.510000        33.910000               0.27000           256.670000
# 25%      11.390000        36.347500               2.93000           445.037500
# 50%      11.980000        37.070000               3.53500           498.890000
# 75%      12.752500        37.720000               4.13000           549.312500
# max      15.130000        40.010000               6.92000           765.520000

# %%
df.isnull().sum()
# Out:
# \tEmail                 0
# Address                 0
# Avatar                  0
# Time on App             0
# Time on Website         0
# Length of Membership    0
# Yearly Amount Spent     0
# dtype: int64

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    print(f"\n--- {col} ---")
    print(df[col].value_counts())
    plt.figure(figsize=(10, 6))
    sns.countplot(x=col, data=df)
    plt.xticks(rotation=45, ha='right')
    plt.title(f'Distribution of {col}')
    plt.show()
# Out:
# --- 	Email ---
# \tEmail
# hannahwilson@davidson.com          1
# mstephenson@fernandez.com          1
# hduke@hotmail.com                  1
# pallen@yahoo.com                   1
# riverarebecca@gmail.com            1
#                                   ..
# denise22@hernandez-townsend.com    1
# youngbarbara@yahoo.com             1
# william25@mcconnell.com            1
# ijones@schaefer-carr.net           1
# heatherhall@yahoo.com              1
# Name: count, Length: 500, dtype: int64
# c:\Users\Aakash\Desktop\Github\Ecomlytics\ecomlytics_env\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 9 (	) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# --- Address ---
# Address
# 49791 Rachel Heights Apt. 898East Drewborough, OR 55919-9528    1
# 835 Frank TunnelWrightmouth, MI 82180-9605                      1
# 4547 Archer CommonDiazchester, CA 06566-8576                    1
# 24645 Valerie Unions Suite 582Cobbborough, DC 99414-7564        1
# 1414 David ThroughwayPort Jason, OH 22070-1220                  1
#                                                                ..
# USNS CardenasFPO AA 85439-9449                                  1
# 019 Elliott Tunnel Suite 190Nicholsbury, WV 60804-4440          1
# 9495 Mary Fall Apt. 777Glassport, ND 17957-5596                 1
# 657 Judith CrossroadHancockchester, VI 75658-5788               1
# 8522 Regina Port Suite 782Port Kaitlin, TX 50501-7264           1
# Name: count, Length: 500, dtype: int64
# --- Avatar ---
# Avatar
# Teal              7
# Cyan              7
# CadetBlue         7
# GreenYellow       7
# SlateBlue         7
#                  ..
# PaleGoldenRod     1
# Coral             1
# NavajoWhite       1
# PaleGreen         1
# LightSlateGray    1
# Name: count, Length: 138, dtype: int64

# %%
numerical_cols = df.select_dtypes(include=['number']).columns
for col in numerical_cols:
    print(f"\n--- {col} ---")
    plt.figure(figsize=(10, 6))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()
    plt.figure(figsize=(10,6))
    sns.boxplot(x=col, data=df)
    plt.title(f'Boxplot of {col}')
    plt.show()
# Out:
# --- Time on App ---
# --- Time on Website ---
# --- Length of Membership ---
# --- Yearly Amount Spent ---

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df[numerical_cols].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %%
df.to_csv("data/Cleaned_Ecommerce_Customers.csv", index=False)

# %%
plt.savefig("static/images/correlation_heatmap.png")
